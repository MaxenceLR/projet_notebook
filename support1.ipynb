# %% [markdown]
# ### create, store, manage, and share your code ..........

# %%
#######"" 1 "" ################
# Créer un nouveau répertoire pour le projet
mkdir projet_notebook
cd projet_notebook

# Initialiser un dépôt Git
git init

# Créer un fichier README.md pour décrire le projet
echo "# Projet Jupyter Notebook" > README.md

# Ajouter le fichier README.md au suivi de Git
git add README.md

#########" 2 " ##############
git add projet.ipynb
git commit -m "Ajout du fichier projetSAE.ipynb et du README.md"


##"4"############
# Ajouter l'URL du dépôt distant
git remote add origin https://github.com/username/projet_notebook.git
git branch -M main
git push -u origin main

##########"5 "#########"
# Créer un fichier .gitignore
echo "*.ipynb_checkpoints/" > .gitignore

# Ajouter le fichier .gitignore au suivi de Git
git add .gitignore
git commit -m "Ajout du fichier .gitignore pour exclure les checkpoints Jupyter"
# Out:
#   Cell In[1], line 3
#     mkdir projet_notebook
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### seaborn: statistical data visualization

# %% [markdown]
# **Seaborn** est une bibliothèque de visualisation de données en Python basée sur Matplotlib. Elle offre une interface de haut niveau pour créer des graphiques statistiques attrayants et informatifs. (https://seaborn.pydata.org/)

# %% [markdown]
# Pour installer Seaborn, utilisez pip dans votre terminal ou environnement :

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Exemple de configuration de style
sns.set(style="dark")  # Choix de style parmi : "darkgrid", "whitegrid", "dark", "white", "ticks"

# %% [markdown]
# #### Visualiser des distributions

# %%
#Histogramme avec Kernel Density Estimate (KDE) 
data = sns.load_dataset("penguins")
sns.histplot(data=data, x="flipper_length_mm", kde=True)
plt.show()

# %%
#Graphique de densité
sns.kdeplot(data=data, x="flipper_length_mm", fill=True)
plt.show()

# %%
#Montrer des relations entre variables
sns.scatterplot(data=data, x="flipper_length_mm", y="body_mass_g", hue="species")
plt.show()

# %%
import seaborn as sns
sns.set_theme(style="ticks")

df = sns.load_dataset("penguins")
sns.pairplot(df, hue="species")

# %% [markdown]
# cette methodes permet de visualiser l'entierter des données ainsi que leur correlations

# %%
sns.set_theme(style="darkgrid")

# Load an example dataset with long-form data
fmri = sns.load_dataset("fmri")

# Plot the responses for different events and regions
sns.lineplot(x="timepoint", y="signal",
             hue="region", style="event",
             data=fmri)
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
cette methode permet de visualiser le intensiter du signal en focntion des diffrents point de mesure

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="ticks")

# Initialize the figure with a logarithmic x axis
f, ax = plt.subplots(figsize=(7, 6))
ax.set_xscale("log")

# Load the example planets dataset
planets = sns.load_dataset("planets")

# Plot the orbital period with horizontal boxes
sns.boxplot(
    planets, x="distance", y="method", hue="method",
    whis=[0, 100], width=.6, palette="vlag"
)

# Add in points to show each observation
sns.stripplot(planets, x="distance", y="method", size=4, color=".3")

# Tweak the visual presentation
ax.xaxis.grid(True)
ax.set(ylabel="")
sns.despine(trim=True, left=True)
